# %% [markdown]
# # Text Preprocessing (Pipeline or NLP) Code

# %%
text = "Natural Language Processing is amazing! I love learning machine learning and NLP."

# %%
text = text.lower()
text # Convert to lower
# Out:
# 'natural language processing is amazing! i love learning machine learning and nlp.'

# %%
text = text.upper()
text # Convert to upper
# Out:
# 'NATURAL LANGUAGE PROCESSING IS AMAZING! I LOVE LEARNING MACHINE LEARNING AND NLP.'

# %%
import string
text = text.translate(str.maketrans("","",string.punctuation))

text # Remove punctuation
# Out:
# 'NATURAL LANGUAGE PROCESSING IS AMAZING I LOVE LEARNING MACHINE LEARNING AND NLP'

# %%
from nltk.tokenize import word_tokenize
word = word_tokenize(text)
word # Tokenize word
# Out:
# ['NATURAL',
#  'LANGUAGE',
#  'PROCESSING',
#  'IS',
#  'AMAZING',
#  'I',
#  'LOVE',
#  'LEARNING',
#  'MACHINE',
#  'LEARNING',
#  'AND',
#  'NLP']

# %%
from nltk.tokenize import sent_tokenize
word = sent_tokenize(text)
word # tokenize sentence
# Out:
# ['NATURAL LANGUAGE PROCESSING IS AMAZING I LOVE LEARNING MACHINE LEARNING AND NLP']

# %%
from nltk.corpus import stopwords
stop_word = stopwords.words('english')
stop_word # stop words mean which do have not meaning
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
p = (ps.stem('playing','running'))
p # cut stem root
# Out:
# 'play'

# %%
word = 'playing','read','rainy'
from nltk.stem import WordNetLemmatizer
w = WordNetLemmatizer()
words = [w.lemmatize(word,pos='v') for word  in words]
words # it is have more word and good also have word from dictionary
# Out:
# ['run', 'run', 'better', 'wolves']

# %%
from sklearn.feature_extraction.text import CountVectorizer

c = CountVectorizer()
X = c.fit_transform([text])
print(X.toarray()) # Bag of words ok so in these we give word a smart code of number to find a same meaning
# Out:
# [[1 1 1 1 2 1 1 1 1 1]]

# %% [markdown]
# # Text Classification using Neural Network  /   Deep Learning Model for NLP

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, SimpleRNN
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# embedding - Converts words into vectors
# Flatten	  - Converts matrix to vector
# Dense     -	Neural network layer

# %%
texts = ["I love machine learning", "Machine learning is amazing", "I enjoy coding"]
labels = [1, 1, 0]

# %%
# Tokenization

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# %%
# Convert to sequecens
sequences = tokenizer.texts_to_sequences(texts)
sequences
# Out:
# [[1, 4, 2, 3], [2, 3, 5, 6], [1, 7, 8]]

# %%
# Padding

max_length = 5

paddi = pad_sequences(sequences, maxlen=5, padding='post')
paddi
# Out:
# array([[1, 4, 2, 3, 0],
#        [2, 3, 5, 6, 0],
#        [1, 7, 8, 0, 0]], dtype=int32)

# %%
# Embedding layer
model = Sequential()
model.add(Embedding(input_dim = 100,output_dim= 8 , input_length=max_length))
model.add(Flatten())
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile model

model.compile(optimizer = 'adam' , loss='binary_crossentropy' , metrics = ['accuracy'] )

# %%
# Train model

model.fit(paddi, np.array(labels), epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 0.6838
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6667 - loss: 0.6815
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6667 - loss: 0.6792
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6667 - loss: 0.6769
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.6748
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.6728
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.6704
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.6679
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.6654
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.6629

# %% [markdown]
# # ANN Model

# %%
ann_model=Sequential()  # ANN (The "Flatten" Approach) - Flattens sequence to static features
ann_model.add(Embedding(input_dim=100,output_dim=10))
ann_model.add(Flatten())
ann_model.add(Dense(10,activation='relu'))
ann_model.add(Dense(1,activation = 'sigmoid'))

# Compile

ann_model.compile(optimizer = 'adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # RNN Model

# %%
rnn_model=Sequential()
rnn_model.add(Embedding(input_dim=100,output_dim=10))
rnn_model.add(SimpleRNN(16))
rnn_model.add(Dense(1, activation='sigmoid'))
rnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #
